# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage

# %%
import requests

# %%
@tool
def multiply(a:int,b:int)->int:
    """multiplication of two numbers"""
    return a*b

# %%
print(multiply.invoke({"a":4,"b":45}))
# Out:
# 180

# %%
print(multiply.name)
print(multiply.description)
print(multiply.args)
# Out:
# multiply
# multiplication of two numbers
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}

# %% [markdown]
# # Tool Binding

# %%
model = HuggingFaceEndpoint(
    repo_id='meta-llama/Llama-3.1-8B-Instruct',
    task='text-generation'
)

llm = ChatHuggingFace(llm=model)

# %%
llm.invoke("hi")
# Out:
# AIMessage(content='Hi! How can I assist you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 11, 'total_tokens': 21}, 'model_name': 'meta-llama/Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0577e-3b1c-71d0-95f2-ef181a196a1e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 10, 'total_tokens': 21})

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
llm_with_tools.invoke("hi, how are you?")
# Out:
# AIMessage(content="I'm doing well, thank you for asking. I'm a large language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to help with any questions or tasks you have. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 222, 'total_tokens': 281}, 'model_name': 'meta-llama/Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0577e-47a2-73e3-8ffb-daa49dd78fe7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 222, 'output_tokens': 59, 'total_tokens': 281})

# %%
query = HumanMessage("can you multiply 3 with 5")

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 5', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tools.invoke(messages)
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 5', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"a": 3, "b": 5}', 'name': 'multiply', 'description': None}, 'id': 'call_ykKnHQwi0gpavjCmAVNkZ161', 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 224, 'total_tokens': 245}, 'model_name': 'meta-llama/Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0577e-a36f-7a50-88e2-3ca5d019bc76-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 5}, 'id': 'call_ykKnHQwi0gpavjCmAVNkZ161', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 224, 'output_tokens': 21, 'total_tokens': 245})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
tool_result
# Out:
# ToolMessage(content='15', name='multiply', tool_call_id='call_ykKnHQwi0gpavjCmAVNkZ161')

# %%
messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content='can you multiply 3 with 5', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"a": 3, "b": 5}', 'name': 'multiply', 'description': None}, 'id': 'call_ykKnHQwi0gpavjCmAVNkZ161', 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 224, 'total_tokens': 245}, 'model_name': 'meta-llama/Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0577e-a36f-7a50-88e2-3ca5d019bc76-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 5}, 'id': 'call_ykKnHQwi0gpavjCmAVNkZ161', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 224, 'output_tokens': 21, 'total_tokens': 245}),
#  ToolMessage(content='15', name='multiply', tool_call_id='call_ykKnHQwi0gpavjCmAVNkZ161')]

# %%
llm_with_tools.invoke(messages).content

# %%
result
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"a": 3, "b": 5}', 'name': 'multiply', 'description': None}, 'id': 'call_yUANQSOkpfRUjVx0XLFjuwHN', 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 254, 'total_tokens': 273}, 'model_name': 'meta-llama/Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a05781-c80e-7081-b0f1-4d95adb1af4e-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 5}, 'id': 'call_yUANQSOkpfRUjVx0XLFjuwHN', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 254, 'output_tokens': 19, 'total_tokens': 273})

# %% [markdown]
# # CUrrency COnversion agent

# %% [markdown]
# ## injectedtool Arg

# %%
# tool create
from langchain_core.tools import InjectedToolArg
from typing import Annotated

@tool
def get_conversion_factor(base_currency: str, target_currency: str) -> float:
  """
  This function fetches the currency conversion factor between a given base currency and a target currency
  """
  url = f'https://v6.exchangerate-api.com/v6/c754eab14ffab33112e380ca/pair/{base_currency}/{target_currency}'

  response = requests.get(url)

  return response.json()

@tool
def convert(base_currency_value: int, conversion_rate: Annotated[float, InjectedToolArg]) -> float:
  """
  given a currency conversion rate this function calculates the target currency value from a given base currency value
  """

  return base_currency_value * conversion_rate

# %%
convert.args
# Out:
# {'base_currency_value': {'title': 'Base Currency Value', 'type': 'integer'}}

# %%
get_conversion_factor.invoke({'base_currency':'USD','target_currency':'INR'})
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1788134402,
#  'time_last_update_utc': 'Mon, 31 Aug 2026 00:00:02 +0000',
#  'time_next_update_unix': 1788220802,
#  'time_next_update_utc': 'Tue, 01 Sep 2026 00:00:02 +0000',
#  'base_code': 'USD',
#  'target_code': 'INR',
#  'conversion_rate': 95.5805}

# %%
convert.invoke({'base_currency_value':10, 'conversion_rate':85.16})
# Out:
# 851.5999999999999

# %%
model = HuggingFaceEndpoint(
    repo_id='meta-llama/Llama-3.1-8B-Instruct',
    task='text-generation'
)

llm = ChatHuggingFace(llm=model)

# %%
llm_with_tool = llm.bind_tools([get_conversion_factor, convert])

# %%
messages = [HumanMessage('What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd , last updated this month')]

# %%
ai_message = llm_with_tools.invoke(messages)

# %%
messages.append(ai_message)

# %%
ai_message
# Out:
# AIMessage(content='The conversion factor between INR and USD can vary depending on the current exchange rate. As of my last update in 2023, the approximate conversion factor is:\n\n1 USD = 77.92 INR\n\nTo convert 10 INR to USD, you can use this conversion factor. To do so, you would divide 10 by the conversion factor, so:\n\n10 INR ÷ 77.92 = 0.128 USD (approximately)\n\nSo, 10 INR is equivalent to approximately 0.128 USD.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 110, 'prompt_tokens': 241, 'total_tokens': 351}, 'model_name': 'meta-llama/Llama-3.1-8B-Instruct', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0578b-4161-7682-b12f-7cfd167e64b7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 241, 'output_tokens': 110, 'total_tokens': 351})

# %%
print(ai_message.tool_calls)
'''
[{'name': 'get_conversion_factor',
  'args': {'base_currency': 'INR', 'target_currency': 'USD'},
  'id': 'call_PKL8v7zwmphzNel0MnvjjGvY',
  'type': 'tool_call'},
 {'name': 'convert',
  'args': {'base_currency_value': 10},
  'id': 'call_vRdld30yHTKFGcTQPumgzH5u',
  'type': 'tool_call'}]'''
# Out:
# []

# %%
import json

for tool_call in ai_message.tool_calls:
  # execute the 1st tool and get the value of conversion rate
  if tool_call['name'] == 'get_conversion_factor':
    tool_message1 = get_conversion_factor.invoke(tool_call)
    # fetch this conversion rate
    conversion_rate = json.loads(tool_message1.content)['conversion_rate']
    # append this tool message to messages list
    messages.append(tool_message1)
  # execute the 2nd tool using the conversion rate from tool 1
  if tool_call['name'] == 'convert':
    # fetch the current arg
    tool_call['args']['conversion_rate'] = conversion_rate
    tool_message2 = convert.invoke(tool_call)
    messages.append(tool_message2)

# %%
messages
'''
[HumanMessage(content='What is the conversion factor between INR and USD, and based on that can you convert 10 inr to usd', additional_kwargs={}, response_metadata={}),
 AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_PKL8v7zwmphzNel0MnvjjGvY', 'function': {'arguments': '{"base_currency": "INR", "target_currency": "USD"}', 'name': 'get_conversion_factor'}, 'type': 'function'}, {'id': 'call_vRdld30yHTKFGcTQPumgzH5u', 'function': {'arguments': '{"base_currency_value": 10}', 'name': 'convert'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 123, 'total_tokens': 176, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BR8rovupYuNnIbGO41TOO3knQ2Cr9', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5ee0506a-8be8-4d32-8f30-f939d59b11a8-0', tool_calls=[{'name': 'get_conversion_factor', 'args': {'base_currency': 'INR', 'target_currency': 'USD'}, 'id': 'call_PKL8v7zwmphzNel0MnvjjGvY', 'type': 'tool_call'}, {'name': 'convert', 'args': {'base_currency_value': 10, 'conversion_rate': 0.0117}, 'id': 'call_vRdld30yHTKFGcTQPumgzH5u', 'type': 'tool_call'}], usage_metadata={'input_tokens': 123, 'output_tokens': 53, 'total_tokens': 176, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
 ToolMessage(content='{"result": "success", "documentation": "https://www.exchangerate-api.com/docs", "terms_of_use": "https://www.exchangerate-api.com/terms", "time_last_update_unix": 1745798401, "time_last_update_utc": "Mon, 28 Apr 2025 00:00:01 +0000", "time_next_update_unix": 1745884801, "time_next_update_utc": "Tue, 29 Apr 2025 00:00:01 +0000", "base_code": "INR", "target_code": "USD", "conversion_rate": 0.0117}', name='get_conversion_factor', tool_call_id='call_PKL8v7zwmphzNel0MnvjjGvY'),
 ToolMessage(content='0.117', name='convert', tool_call_id='call_vRdld30yHTKFGcTQPumgzH5u')]'''

# %%
llm_with_tools.invoke(messages).content
"""The conversion factor between INR and USD is 0.0117. 

Based on this conversion factor, 10 INR is equal to 0.117 USD."""

# %%
from langchain.agents import initialize_agent, AgentType

# Step 5: Initialize the Agent ---
agent_executor = initialize_agent(
    tools=[get_conversion_factor, convert],
    llm=llm,
    agent=AgentType.STRUCTURED_CHAT_ZERO_SHOT_REACT_DESCRIPTION,  # using ReAct pattern
    verbose=True  # shows internal thinking
)

# %%
# --- Step 6: Run the Agent ---
user_query = "Hi how are you?"

response = agent_executor.invoke({"input": user_query})
